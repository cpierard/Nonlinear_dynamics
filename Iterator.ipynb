# %%
using PyPlot

# %%
include("simple_ODE_solvers.jl")
# Out:
# iterator (generic function with 1 method)

# %%
?simple_euler
# Out:
# search: simple_euler
# ```
#   simple_euler(f, n, x0, dt)
#   OUT: array_solutions, array_time
# ```
#
# Is the simple Euler's method for solving ODEs. Where f is the function of type x' = f(x), n is the number of steps, `x0` is the initial condition, and `dt` is the time step.

# %%
function iterator(f::Function, n::Int, x0)
    
    solution = Float64[x0]
    steps = Int[0]
    x_old = x0
    for i in 1:n
        
        x_new = f(solution[i])
        push!(solution, x_new)
        push!(steps, i)
        
    end
    
    return steps, solution
    
end
# Out:
# iterator (generic function with 1 method)

# %%
f(x) = 3(x -x^2)
const r = 1.0
# Out:
# 1.0

# %%
N, tray = iterator(f, 100, 0.9)
plot(N, tray)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x313096490>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x313ade510>

# %%
plot(N, tray)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x312a0eb50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x312c23c10>

# %%
?list
# Out:
# search: listen listenany InvalidStateException lcfirst normalize_string
#
# Couldn't find list
# Perhaps you meant last, hist, listen, less, let, filt, Cint, Dict, Test or cis
# LoadError: "list" is not defined in module Main
# while loading In[54], in expression starting on line 119
#
#  in error at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in which_module at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
#  in call at /Applications/Julia-0.4.6.app/Contents/Resources/julia/lib/julia/sys.dylib
